# %%
import pandas as pd
import os
import torch
import torchaudio
from torchaudio import transforms
from torchaudio.utils import download_asset
import random
import matplotlib.pyplot as plt
#Loading the data

listed_files_train = [] #Creating a list to remove inappropriate data
current_path_train = "C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualTrain/"
x_train =  os.listdir("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualTrain")  
for train_path in x_train:
    listed_files_train.append(train_path)
listed_files_train.remove(listed_files_train[0])
print(listed_files_train)

#Creating the main class, which will have necessary methods

class AudioUtil():
    
    #loading and reading the files
   
    @staticmethod
    def file_open(audio_file):
        sig, sr = torchaudio.load(audio_file)
        return sig, sr
    
    #Equalizing the sample sizes
    
    @staticmethod
    def pad_trunc(aud, max_ms):
        sig, sr = aud
        num_rows, sig_len = sig.shape
        max_len = sr//1000 * max_ms

        if (sig_len > max_len):
            sig = sig[:,:max_len]

        elif (sig_len < max_len):
            pad_begin_len = random.randint(0, max_len - sig_len)
            pad_end_len = max_len - sig_len - pad_begin_len

            pad_begin = torch.zeros((num_rows, pad_begin_len))
            pad_end = torch.zeros((num_rows, pad_end_len))

            sig = torch.cat((pad_begin, sig, pad_end), 1)
      
        return (sig, sr)
    
    #Shifting time. (For now, I don't know what I should add in the second parameter when testing)
    
    @staticmethod
    def time_shift(aud, shift_limit):
        sig,sr = aud
        _, sig_len = sig.shape
        shift_amt = int(random.random() * shift_limit * sig_len)
        return (sig.roll(shift_amt), sr)
    
    # Mel spectrogram
    
    @staticmethod
    def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
        sig,sr = aud
        top_db = 80

        # spec has shape [channel, n_mels, time], where channel is mono, stereo etc
        spec = transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)

        # Convert to decibels
        spec = transforms.AmplitudeToDB(top_db=top_db)(spec)
        return (spec)
    
    # Augemented Mel spectrogram
    
    @staticmethod
    def spectro_augment(spec, max_mask_pct=0.1, n_freq_masks=1, n_time_masks=1):
        _, n_mels, n_steps = spec.shape
        mask_value = spec.mean()
        aug_spec = spec

        freq_mask_param = max_mask_pct * n_mels
        for _ in range(n_freq_masks):
            aug_spec = transforms.FrequencyMasking(freq_mask_param)(aug_spec, mask_value)

        time_mask_param = max_mask_pct * n_steps
        for _ in range(n_time_masks):
            aug_spec = transforms.TimeMasking(time_mask_param)(aug_spec, mask_value)

        return aug_spec
#Testing the output
for link_train in listed_files_train:
    open_link_train = AudioUtil.file_open(link_train)
    link_train_resize = AudioUtil.pad_trunc(open_link_train,10000)
    link_train_shifted = AudioUtil.time_shift(link_train_resize,1000)
    mel_spect = AudioUtil.spectro_gram(aud = link_train_resize)
    augmented_spect = AudioUtil.spectro_augment(spec = mel_spect)
    #print(mel_spect)
    #print(augmented_spect) 
print(augmented_spect.shape)
# Out:
# ['Azanicadazuluensis_MHV%20936%20A.zuluensis%20Mission%20Rock%20%232.wav', 'Azanicadazuluensis_MHV%20937%20A.zuluensis%20Trafalgar.wav', 'Brevisianabrevis_MHV%201408%20Brevisiana%20brevis%20Dedza.wav', 'Brevisianabrevis_MHV%20959%20B.brevis%20Morningside%20Ranch%20%233.wav', 'Brevisianabrevis_MHV%20959%20B.brevis%20Morningside%20Ranch%20%234.wav', 'Chorthippusbiguttulus_CHOBIG_20190906_163909.M.wav', 'Chorthippusbiguttulus_CHOBIG_20190906_164243.M.wav', 'Chorthippusbiguttulus_dat001-018.M.wav', 'Chorthippusbiguttulus_dat001-053.M.wav', 'Chorthippusbiguttulus_dat003-040.M.wav', 'Chorthippusbiguttulus_dat005-025.M.wav', 'Chorthippusbiguttulus_dat005-056.M.wav', 'Chorthippusbiguttulus_dat028-023.wav', 'Chorthippusbiguttulus_dat149-002.wav', 'Chorthippusbiguttulus_dat179-001.wav', 'Chorthippusbiguttulus_dat185-002.wav', 'Chorthippusbiguttulus_file0224.M.wav', 'Chorthippusbiguttulus_NoID_20210729_115824.M.wav', 'Chorthippusbiguttulus_Take45.M.wav', 'Chorthippusbrunneus_CHOBRU_20180914_141
# ...

# %%
#Adjust this to the csv version 
listed_files_valid = []
current_path_valid = "C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualValidation"
x_valid =  os.scandir("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualValidation")  
for valid_path in x_valid:
    listed_files_valid.append(valid_path)
listed_files_valid.remove(listed_files_valid[0])
for link_valid in listed_files_valid:
    metadata_valid = torchaudio.info(link_valid)
    print(metadata_valid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 listed_files_valid = []
#       2 current_path_valid = "C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualValidation"
# ----> 3 x_valid =  os.scandir("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualValidation")
#       4 for valid_path in x_valid:
#       5     listed_files_valid.append(valid_path)
#
# NameError: name 'os' is not defined

# %%
#Adjust this to the csv version 
listed_files_test = []
current_path_test = "C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualTrain"
x =  os.scandir("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualTrain")  
for test_path in x:
    listed_files_test.append(test_path)
listed_files_test.remove(listed_files_test[0])
for link_test in listed_files_test:
    metadata_test = torchaudio.info(link_test)
    print(metadata_test)
# Out:
# AudioMetaData(sample_rate=44100, num_frames=441000, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# AudioMetaData(sample_rate=44100, num_frames=441000, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# AudioMetaData(sample_rate=44100, num_frames=441000, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# AudioMetaData(sample_rate=44100, num_frames=441000, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# AudioMetaData(sample_rate=44100, num_frames=441000, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# AudioMetaData(sample_rate=44100, num_frames=313661, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# AudioMetaData(sample_rate=44100, num_frames=293077, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# AudioMetaData(sample_rate=44100, num_frames=394560, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# AudioMetaData(sample_rate=44100, num_frames=395573, num_channels=1, bits_per_sample=16, encoding=PCM_S)
# ...

# %%
import pandas as pd

#Use this code in your own directory to create a csv. Change the paths to your needs and whether you need validation or
#test data file. If anything fails, I'll look into it where I missed to inform you

#Creating a list to remove inappropriate data
listed_files_train = []
listed_files_test = []
listed_files_val = []
#current_path_train = "C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualTrain/"
x_train = os.listdir("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualTrain")
x_test = os.listdir("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualTest")
x_val = os.listdir("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/ManualValidation")

#creating the lists and removing the first element, not being a .wav file
for train_path in x_train:
    listed_files_train.append(train_path)
listed_files_train.remove(listed_files_train[0])

for test_path in x_test:
    listed_files_test.append(test_path)
listed_files_test.remove(listed_files_test[0])

for val_path in x_val:
    listed_files_val.append(val_path)
listed_files_val.remove(listed_files_val[0])
    

training_label_list = []
for i in range (0,2): #Azanicadazuluensis
    training_label_list.append(1)
for i in range (0,3): #Brevisiniabrevis
    training_label_list.append(2)
for i in range (0,14): #Chorthippusbiguttulus, EDITED
    training_label_list.append(32)  #32 claimed here
for i in range (0,9): #Chorthippusbrunneus, EDITED
    training_label_list.append(3)
for i in range (0,15): #Grylluscampestris
    training_label_list.append(4)
for i in range (0,3):  #Kikihiamuta
    training_label_list.append(5)
for i in range (0,4):  #Myopsaltaleona
    training_label_list.append(6)
for i in range (0,2):  #Myopsaltalongicauda
    training_label_list.append(7)
for i in range (0,4):  #Myopsaltamackinlayi
    training_label_list.append(8)
for i in range (0,2):  #Myopsaltamelonbasis
    training_label_list.append(9)
for i in range (0,3):  #Myopsaltaxerograsidia
    training_label_list.append(10)
for i in range (0,13): #Nemobiussylvestris
    training_label_list.append(11)
for i in range (0,9):  #Oecanthuspellucens
    training_label_list.append(12)
for i in range (0,17): #Pholidopteragriseoaptera
    training_label_list.append(13)
for i in range (0,4):  #Platypleuracapensis
    training_label_list.append(14)
for i in range (0,15): #Platypleuracfcatenata
    training_label_list.append(15)
for i in range (0,4):  #Platypleurachalybaea
    training_label_list.append(16)
for i in range (0,6):  #Platypleuradeusta
    training_label_list.append(17)
for i in range (0,3):  #Platyplearadivisa
    training_label_list.append(18)
for i in range (0,2):  #Platypleurahaglundi
    training_label_list.append(19)
for i in range (0,3):  #Platypleurahirtipennis
    training_label_list.append(20)
for i in range (0,2):  #Platypleuraintercapendinis
    training_label_list.append(21)
for i in range (0,13): #Platypleuraplumosa
    training_label_list.append(22)
for i in range (0,5):  #Platyplearasp 4
    training_label_list.append(23)
for i in range (0,11): #Platyplearasp 10
    training_label_list.append(24)
for i in range (0,2): #Platyplearasp 11
    training_label_list.append(25)
for i in range (0,6): #Platyplearasp 12
    training_label_list.append(26)
for i in range (0,7): #Platyplearasp 13
    training_label_list.append(27)
for i in range (0,11): #Pseudochortihippusparallelus
    training_label_list.append(28)
for i in range (0,5):  #Pycnasemiclara
    training_label_list.append(29)
for i in range (0,7):  #Roeselianaroeselii
    training_label_list.append(30)
for i in range (0,11): #Tettigoniaviridissima
    training_label_list.append(31)
#32 reserved earlier in list

test_label_list = []
for i in range (0,1): #Azanicadazuluensis
    test_label_list.append(1)
for i in range (0,1): #Brevisiniabrevis
    test_label_list.append(2)
for i in range (0,3): #Chorthippusbiguttulus
    test_label_list.append(32)  #32 claimed here
for i in range (0,2): #Chorthippusbrunneus
    test_label_list.append(3)
for i in range (0,4): #Grylluscampestris
    test_label_list.append(4)
for i in range (0,2):  #Kikihiamuta
    test_label_list.append(5)
for i in range (0,2):  #Myopsaltaleona
    test_label_list.append(6)
for i in range (0,1):  #Myopsaltalongicauda
    test_label_list.append(7)
for i in range (0,2):  #Myopsaltamackinlayi
    test_label_list.append(8)
for i in range (0,2):  #Myopsaltamelonbasis
    test_label_list.append(9)
for i in range (0,2):  #Myopsaltaxerograsidia
    test_label_list.append(10)
for i in range (0,3): #Nemobiussylvestris
    test_label_list.append(11)
for i in range (0,3):  #Oecanthuspellucens
    test_label_list.append(12)
for i in range (0,3): #Pholidopteragriseoaptera
    test_label_list.append(13)
for i in range (0,1):  #Platypleuracapensis
    test_label_list.append(14)
for i in range (0,4): #Platypleuracfcatenata
    test_label_list.append(15)
for i in range (0,2):  #Platypleurachalybaea
    test_label_list.append(16)
for i in range (0,2):  #Platypleuradeusta
    test_label_list.append(17)
for i in range (0,2):  #Platyplearadivisa
    test_label_list.append(18)
for i in range (0,2):  #Platypleurahaglundi
    test_label_list.append(19)
for i in range (0,2):  #Platypleurahirtipennis
    test_label_list.append(20)
for i in range (0,2):  #Platypleuraintercapendinis
    test_label_list.append(21)
for i in range (0,4): #Platypleuraplumosa
    test_label_list.append(22)
for i in range (0,2):  #Platyplearasp 4
    test_label_list.append(23)
for i in range (0,3): #Platyplearasp 10
    test_label_list.append(24)
for i in range (0,1): #Platyplearasp 11
    test_label_list.append(25)
for i in range (0,2): #Platyplearasp 12
    test_label_list.append(26)
for i in range (0,3): #Platyplearasp 13
    test_label_list.append(27)
for i in range (0,3): #Pseudochortihippusparallelus
    test_label_list.append(28)
for i in range (0,2):  #Pycnasemiclara
    test_label_list.append(29)
for i in range (0,3):  #Roeselianaroeselii
    test_label_list.append(30)
for i in range (0,3): #Tettigoniaviridissima
    test_label_list.append(31)
#32 reserved earlier in list
#print(test_label_list)
#print(len(test_label_list)) #matches

val_label_list = []
for i in range (0,1): #Azanicadazuluensis
    val_label_list.append(1)
for i in range (0,1): #Brevisiniabrevis
    val_label_list.append(2)
for i in range (0,3): #Chorthippusbiguttulus
    val_label_list.append(32)  #32 claimed here
for i in range (0,2): #Chorthippusbrunneus
    val_label_list.append(3)
for i in range (0,3): #Grylluscampestris
    val_label_list.append(4)
for i in range (0,1):  #Kikihiamuta
    val_label_list.append(5)
for i in range (0,1):  #Myopsaltaleona
    val_label_list.append(6)
for i in range (0,1):  #Myopsaltalongicauda
    val_label_list.append(7)
for i in range (0,1):  #Myopsaltamackinlayi
    val_label_list.append(8)
for i in range (0,1):  #Myopsaltamelonbasis
    val_label_list.append(9)
for i in range (0,1):  #Myopsaltaxerograsidia
    val_label_list.append(10)
for i in range (0,2): #Nemobiussylvestris
    val_label_list.append(11)
for i in range (0,2):  #Oecanthuspellucens
    val_label_list.append(12)
for i in range (0,2): #Pholidopteragriseoaptera
    val_label_list.append(13)
for i in range (0,1):  #Platypleuracapensis
    val_label_list.append(14)
for i in range (0,3): #Platypleuracfcatenata
    val_label_list.append(15)
for i in range (0,1):  #Platypleurachalybaea
    val_label_list.append(16)
for i in range (0,1):  #Platypleuradeusta
    val_label_list.append(17)
for i in range (0,1):  #Platyplearadivisa
    val_label_list.append(18)
for i in range (0,1):  #Platypleurahaglundi
    val_label_list.append(19)
for i in range (0,1):  #Platypleurahirtipennis
    val_label_list.append(20)
for i in range (0,1):  #Platypleuraintercapendinis
    val_label_list.append(21)
for i in range (0,2): #Platypleuraplumosa
    val_label_list.append(22)
for i in range (0,1):  #Platyplearasp 4
    val_label_list.append(23)
for i in range (0,2): #Platyplearasp 10
    val_label_list.append(24)
for i in range (0,1): #Platyplearasp 11
    val_label_list.append(25)
for i in range (0,2): #Platyplearasp 12
    val_label_list.append(26)
for i in range (0,2): #Platyplearasp 13
    val_label_list.append(27)
for i in range (0,3): #Pseudochortihippusparallelus
    val_label_list.append(28)
for i in range (0,2):  #Pycnasemiclara
    val_label_list.append(29)
for i in range (0,2):  #Roeselianaroeselii
    val_label_list.append(30)
for i in range (0,2): #Tettigoniaviridissima
    val_label_list.append(31)
#32 reserved earlier in list
#print(val_label_list)
#print(len(val_label_list)) #matches

# creating a df containing the paths with correct labels. This only works in a local server, as the files in your drive are 
# not in alphabetical order

#training_df = pd.DataFrame({"path": listed_files_train, "label": training_label_list})
#print(training_df)

#test_df = pd.DataFrame({"path": listed_files_test, "label": test_label_list})
#print(test_df)

#val_df = pd.DataFrame({"path": listed_files_val, "label": val_label_list})
#print(val_df)

#uncomment this to create your df. The parameter is where you want to store the df, recommended next to the data folders.
#training_df.to_csv("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/training_csv.csv")
#test_df.to_csv("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/test_csv.csv")
#val_df.to_csv("C:/Users/carlv/Downloads/insectsound_MariusFaißMSc/val_csv.csv")
# Out:
# 51

# %%
import pandas as pd
import os
import torch
import torchaudio
from torchaudio import transforms
from torchaudio.utils import download_asset
import random
import matplotlib.pyplot as plt





#Creating the main class, which will have necessary methods for preprocessing

class AudioUtil():
    
    #loading and reading the files
   
    @staticmethod
    def file_open(audio_file):
        sig, sr = torchaudio.load(audio_file)
        return sig, sr
    
    #Creating two channels

    @staticmethod
    def rechannel(aud, new_channel):
        sig, sr = aud

        if (sig.shape[0] == new_channel):
        # Nothing to do
            return aud

        if (new_channel == 1):
        # Convert from stereo to mono by selecting only the first channel
            resig = sig[:1, :]
        else:
        # Convert from mono to stereo by duplicating the first channel
            resig = torch.cat([sig, sig])

            return ((resig, sr))

    # Resampling
    
    @staticmethod
    def resample(aud, newsr):
        sig, sr = aud

        if (sr == newsr):
        # Nothing to do
            return aud

        num_channels = sig.shape[0]
      # Resample first channel
        resig = torchaudio.transforms.Resample(sr, newsr)(sig[:1,:])
        if (num_channels > 1):
        # Resample the second channel and merge both channels
            retwo = torchaudio.transforms.Resample(sr, newsr)(sig[1:,:])
            resig = torch.cat([resig, retwo])

        return ((resig, newsr))
    
    #Equalizing the sample sizes
    
    @staticmethod
    def pad_trunc(aud, max_ms):
        sig, sr = aud
        num_rows, sig_len = sig.shape
        max_len = sr//1000 * max_ms

        if (sig_len > max_len):
            sig = sig[:,:max_len]

        elif (sig_len < max_len):
            pad_begin_len = random.randint(0, max_len - sig_len)
            pad_end_len = max_len - sig_len - pad_begin_len

            pad_begin = torch.zeros((num_rows, pad_begin_len))
            pad_end = torch.zeros((num_rows, pad_end_len))

            sig = torch.cat((pad_begin, sig, pad_end), 1)
      
        return (sig, sr)
    
    #Shifting time. (For now, I don't know what I should add in the second parameter when testing)
    
    @staticmethod
    def time_shift(aud, shift_limit):
        sig,sr = aud
        _, sig_len = sig.shape
        shift_amt = int(random.random() * shift_limit * sig_len)
        return (sig.roll(shift_amt), sr)
    
    # Mel spectrogram
    
    @staticmethod
    def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
        sig,sr = aud
        top_db = 80

        # spec has shape [channel, n_mels, time], where channel is mono, stereo etc
        spec = transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)

        # Convert to decibels
        spec = transforms.AmplitudeToDB(top_db=top_db)(spec)
        return (spec)
    
    # Augemented Mel spectrogram
    
    @staticmethod
    def spectro_augment(spec, max_mask_pct=0.1, n_freq_masks=2, n_time_masks=2):
        _, n_mels, n_steps = spec.shape
        mask_value = spec.mean()
        aug_spec = spec

        freq_mask_param = max_mask_pct * n_mels
        for _ in range(n_freq_masks):
            aug_spec = transforms.FrequencyMasking(freq_mask_param)(aug_spec, mask_value)

        time_mask_param = max_mask_pct * n_steps
        for _ in range(n_time_masks):
            aug_spec = transforms.TimeMasking(time_mask_param)(aug_spec, mask_value)

        return aug_spec

# %%
from torch.utils.data import DataLoader, Dataset

#These are just for working on colab, this has to be changed
current_path_train = "/content/drive/MyDrive/Colab Notebooks/Software engineering/ManualTrain/"
current_path_val = "/content/drive/MyDrive/Colab Notebooks/Software engineering/ManualValidation/"


# get file directories and labels from csv file
listed_files_train = []
#dataframe containing the name of the file and the classification label, this is just for colab
train_path_label = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Software engineering/training_csv.csv')
val_path_label = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Software engineering/val_csv.csv')
for train_path in train_path_label["path"]:
    train_path = current_path_train + train_path
    listed_files_train.append(train_path)

class SoundDS(Dataset):
    def __init__(self, df, data_path):
        self.df = df
        self.data_path = str(data_path)
        self.duration = 4000
        self.sr = 44100
        self.channel = 2
        self.shift_pct = 0.4
            
  # ----------------------------
  # Number of items in dataset
  # ----------------------------
  def __len__(self):
    return len(self.df)    
    
  # ----------------------------
  # Get i'th item in dataset
  # ----------------------------
  def __getitem__(self, idx):
    # Absolute file path of the audio file - concatenate the audio directory with
    # the relative path
    audio_file = self.data_path + self.df.loc[idx, 'path']
    # Get the Class ID
    class_id = self.df.loc[idx, 'label']

    aud = AudioUtil.file_open(audio_file)
    # Some sounds might have a higher sample rate, or fewer channels compared to the
    # majority. So make all sounds have the same number of channels and same 
    # sample rate. Unless the sample rate is the same, the pad_trunc will still
    # result in arrays of different lengths, even though the sound duration is
    # the same.
    reaud = AudioUtil.resample(aud, self.sr)
    rechan = AudioUtil.rechannel(reaud, self.channel)
    dur_aud = AudioUtil.pad_trunc(rechan, self.duration)
    shift_aud = AudioUtil.time_shift(dur_aud, self.shift_pct)
    sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
    aug_sgram = AudioUtil.spectro_augment(sgram, max_mask_pct=0.1, n_freq_masks=2, n_time_masks=2)
    aug_sgram = aug_sgram.squeeze(0)
    return aug_sgram, class_id

trainingDS = SoundDS(train_path_label, current_path_train)
val_DS = SoundDS(val_path_label, current_path_val)
train_dl = torch.utils.data.DataLoader(trainingDS, batch_size=16, shuffle=True)
val_dl = torch.utils.data.DataLoader(val_DS, batch_size=16, shuffle=False)

# %%
import torch.nn.functional as F
import torch.nn as nn
from torch.nn import init

# ----------------------------
# Audio Classification Model
# ----------------------------
class AudioClassifier (nn.Module):
    # ----------------------------
    # Build the model architecture
    # ----------------------------
    def __init__(self):
        super().__init__()
        conv_layers = []

        # First Convolution Block with Relu and Batch Norm. Use Kaiming Initialization
        self.conv1 = nn.Conv2d(2, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(8)
        init.kaiming_normal_(self.conv1.weight, a=0.1)
        self.conv1.bias.data.zero_()
        conv_layers += [self.conv1, self.relu1, self.bn1]

        # Second Convolution Block
        self.conv2 = nn.Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm2d(16)
        init.kaiming_normal_(self.conv2.weight, a=0.1)
        self.conv2.bias.data.zero_()
        conv_layers += [self.conv2, self.relu2, self.bn2]

        # Second Convolution Block
        self.conv3 = nn.Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu3 = nn.ReLU()
        self.bn3 = nn.BatchNorm2d(32)
        init.kaiming_normal_(self.conv3.weight, a=0.1)
        self.conv3.bias.data.zero_()
        conv_layers += [self.conv3, self.relu3, self.bn3]

        # Second Convolution Block
        self.conv4 = nn.Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu4 = nn.ReLU()
        self.bn4 = nn.BatchNorm2d(64)
        init.kaiming_normal_(self.conv4.weight, a=0.1)
        self.conv4.bias.data.zero_()
        conv_layers += [self.conv4, self.relu4, self.bn4]

        # Linear Classifier
        self.ap = nn.AdaptiveAvgPool2d(output_size=1)
        self.lin = nn.Linear(in_features=64, out_features=33)

        # Wrap the Convolutional Blocks
        self.conv = nn.Sequential(*conv_layers)
 
    # ----------------------------
    # Forward pass computations
    # ----------------------------
    def forward(self, x):
        # Run the convolutional blocks
        x = self.conv(x)

        # Adaptive pool and flatten for input to linear layer
        x = self.ap(x)
        x = x.view(x.shape[0], -1)

        # Linear layer
        x = self.lin(x)

        # Final output
        return x

# Create the model and put it on the GPU if available
myModel = AudioClassifier()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
myModel = myModel.to(device)
# Check that it is on Cuda
next(myModel.parameters()).device

# %%
# ----------------------------
# Training Loop
# ----------------------------
def training(model, train_dl, num_epochs):
  # Loss Function, Optimizer and Scheduler
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001,
                                                steps_per_epoch=int(len(train_dl)),
                                                epochs=num_epochs,
                                                anneal_strategy='linear')

  # Repeat for each epoch
    for epoch in range(num_epochs):
        running_loss = 0.0
        correct_prediction = 0
        total_prediction = 0

        # Repeat for each batch in the training set
        for i, data in enumerate(train_dl):
            # Get the input features and target labels, and put them on the GPU
            inputs, labels = data[0].to(device), data[1].to(device)
            # Normalize the inputs
            inputs_m, inputs_s = inputs.mean(), inputs.std()
            inputs = (inputs - inputs_m) / inputs_s

            # Zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)
            print(outputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()

            # Keep stats for Loss and Accuracy
            running_loss += loss.item()

            # Get the predicted class with the highest score
            _, prediction = torch.max(outputs,1)
            # Count of predictions that matched the target label
            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]

            #if i % 10 == 0:    # print every 10 mini-batches
            #    print('[%d, %5d] loss: %.3f' % (epoch + 1, i + 1, running_loss / 10))

        # Print stats at the end of the epoch
        num_batches = len(train_dl)
        avg_loss = running_loss / num_batches
        acc = correct_prediction/total_prediction
        print(f'Epoch: {epoch}, Loss: {avg_loss:.2f}, Accuracy: {acc:.2f}')

    print('Finished Training')

num_epochs=70   # adjustments needed
training(myModel, train_dl, num_epochs)

# %%
#Validation

def inference (model, val_dl):
    correct_prediction = 0
    total_prediction = 0

      # Disable gradient updates
    with torch.no_grad():
        for data in val_dl:
            # Get the input features and target labels, and put them on the GPU
            inputs, labels = data[0].to(device), data[1].to(device)

              # Normalize the inputs
            inputs_m, inputs_s = inputs.mean(), inputs.std()
            inputs = (inputs - inputs_m) / inputs_s

                  # Get predictions
            outputs = model(inputs)

                  # Get the predicted class with the highest score
            _, prediction = torch.max(outputs,1)
                  # Count of predictions that matched the target label
            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]

    acc = correct_prediction/total_prediction
    print(f'Accuracy: {acc:.2f}, Total items: {total_prediction}')

# Run inference on trained model with the validation set
inference(myModel, val_dl)
